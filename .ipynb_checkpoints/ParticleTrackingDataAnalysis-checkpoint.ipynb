# %% [markdown]
# # Particle Tracking

# %%
from Blobfinder import *
from PIL import Image
import numpy as np

# %%
def Tracker(P, tau, deltap):
   
    distances = []


    for i in range(9):       #first 9 frames
        im1 = Image.open('run3/frame0000'+str(i)+'.jpg')
        im2 = Image.open('run3/frame0000'+str(i+1)+'.jpg')
        lst1 = BlobFinder(im1, tau) #finds blobs in frame 
        Bead1 = getBeads(P, lst1) #returns a list of beads over P pixels for frame
        lst2 = BlobFinder(im2, tau) #finds blobs in next frame
        Bead2 = getBeads(P, lst2) #returns list of beads over P pixels for frame
        for blob in range(len(Bead1)):
            if blob < len(Bead2):     #takes the same bead index for eact list of blobs from blob finder
                distance = Bead1[blob].distanceTo(Bead2[blob]) #and finds the distance
                if distance <= deltap:
                    distances.append(distance)  #if that distance is over deltap, appends it to a list
    
    for i in range(10,99): #same for frames 10-99
        im1 = Image.open('run3/frame000'+str(i)+'.jpg')
        im2 = Image.open('run3/frame000'+str(i+1)+'.jpg')
        lst1 = BlobFinder(im1, tau)
        Bead1 = getBeads(P, lst1)
        lst2 = BlobFinder(im2, tau)
        Bead2 = getBeads(P, lst2)
        for blob in range(len(Bead1)):
            if blob < len(Bead2):
                distance = Bead1[blob].distanceTo(Bead2[blob])
                if distance <= deltap:
                    distances.append(distance)
    
    for i in range(100,199): #same for frames 100-200
        im1 = Image.open('run3/frame00'+str(i)+'.jpg')
        im2 = Image.open('run3/frame00'+str(i+1)+'.jpg')
        lst1 = BlobFinder(im1, tau)
        Bead1 = getBeads(P, lst1)
        lst2 = BlobFinder(im2, tau)
        Bead2 = getBeads(P, lst2)
        for blob in range(len(Bead1)):
            if blob < len(Bead2):
                distance = Bead1[blob].distanceTo(Bead2[blob])
                if distance <= deltap:
                    distances.append(distance)
    
    np.savetxt('RadialDistances.txt', distances, fmt='%.4f', header = 'Radial Distance traveled by Beads')
    return 'RadialDistances.txt'  #writes distances to file

# %%
distances = Tracker(25, 600, 20)
# !cat 'RadialDistances.txt'
# Out:
# # Radial Distance traveled by Beads
# 2.2361
# 9.8489
# 3.6056
# 4.0000
# 5.8310
# 5.0000
# 2.2361
# 3.6056
# 1.0000
# 1.4142
# 3.1623
# 8.4853
# 4.4721
# 3.1623
# 3.1623
# 6.7082
# 3.6056
# 6.7082
# 6.7082
# 3.1623
# 3.1623
# 7.0711
# 6.7082
# 2.2361
# 8.0623
# 1.0000
# 5.6569
# 2.8284
# 5.0000
# 5.0000
# 6.4031
# 1.4142
# 6.7082
# 2.2361
# 10.0499
# 8.0000
# 5.0990
# 3.1623
# 12.0416
# 7.2801
# 3.1623
# 5.0000
# 9.8489
# 2.2361
# 6.7082
# 6.0000
# 6.0828
# 2.2361
# 9.4868
# 9.4868
# 4.1231
# 5.0000
# 3.1623
# 6.0828
# 3.1623
# 3.6056
# 3.0000
# 3.0000
# 3.0000
# 2.0000
# 2.8284
# 3.6056
# 6.0828
# 6.3246
# 2.2361
# 2.0000
# 11.0454
# 5.8310
# 6.4031
# 10.6301
# 2.0000
# 5.0000
# 9.4868
# 6.4031
# 16.1245
# 6.7082
# 3.1623
# 1.4142
# 1.0000
# 2.8284
# 2.8284
# 4.4721
# 1.0000
# 2.0000
# 3.6056
# 5.3852
# 4.2426
# 4.1231
# 3.1623
# 3.0000
# 4.4721
# 5.0000
# 5.3852
# 7.2801
# 4.2426
# 7.6158
# 7.8102
# 5.0000
# 11.3137
# 7.2801
# 1.0000
# 5.0990
# 6.4031
# 9.8995
# 5.3852
# 2.2361
# 2.2361
# 2.0000
# 3.1623
# 6.4031
# 3.6056
# 6.4031
# 4.0000
# 10.6301
# 1.0000
# 6.3246
# 4.0000
# 4.2426
# 6.4031
# 2.2361
# 2.2361
# 5.0000
# 5.3852
# 3.1623
# 9.4868
# 3.0000
# 10.7703
# 6.3246
# 3.0000
# 1.0000
# 7.0711
# 3.1623
# 4.1231
# 5.0990
# 2.2361
# 1.0000
# 7.0000
# 5.0000
# 9.8489
# 0.0000
# 3.1623
# 2.8284
# 3.1623
# 5.0990
# 1.4142
# 5.8310
# 9.0000
# 7.0711
# 13.1529
# 13.0384
# 5.0990
# 3.1623
# 5.8310
# 6.4031
# 8.4853
# 5.0000
# 5.0000
# 4.4721
# 3.0000
# 3.6056
# 4.4721
# 6.3246
# 4.4721
# 4.4721
# 6.0828
# 5.0990
# 3.0000
# 5.3852
# 5.3852
# 5.3852
# 5.0990
# 8.0623
# 5.0000
# 3.0000
# 1.4142
# 5.3852
# 2.8284
# 2.0000
# 12.0416
# 6.7082
# 7.2801
# 7.2801
# 6.0828
# 6.4031
# 4.1231
# 8.9443
# 6.0828
# 4.4721
# 3.1623
# 5.0000
# 2.2361
# 5.0000
# 3.1623
# 4.0000
# 6.7082
# 7.8102
# 1.0000
# 7.0711
# 2.2361
# 2.2361
# 6.0828
# 11.6619
# 7.2801
# 1.0000
# 5.0990
# 3.1623
# 7.0711
# 8.0623
# 2.2361
# 1.4142
# 1.4142
# 7.0711
# 5.0990
# 2.8284
# 4.2426
# 1.4142
# 1.0000
# 7.6158
# 5.3852
# 7.6158
# 5.0990
# 7.2801
# 5.3852
# 3.6056
# 5.0000
# 10.0000
# 3.0000
# 10.0000
# 3.6056
# 4.4721
# 5.0000
# 1.4142
# 5.3852
# 3.0000
# 8.6023
# 4.1231
# 4.2426
# 2.0000
# 4.1231
# 5.3852
# 3.6056
# 10.4403
# 3.6056

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### self diffusion constant

# %% [markdown]
#     conversion factor = 0.175$10^{-6}$

# %% [markdown]
# ### Estimating the Boltzmann constant

# %% [markdown]
#      k = Boltzmann constant = 6(Dπηρ)/T
#      η = viscosity of water = 9.135$10^{-4}$ N*s/m2
#      ρ = radius of bead = 0.5$10^{-6}$ meters
#      T = 297 degrees Kelvin

# %% [markdown]
# ### Estimating Avogadro's number

# %% [markdown]
#     Na = Avagadro's number = R/k
#     R = gas constant = 8.31457 J/K⋅mol

# %% [markdown]
# ## Function

# %%
def EstimateAvagadrosNumber(fileofradialdistances):
    r = 0
    conversion = 0.175e-6
    for distance in np.loadtxt(fileofradialdistances):
        r += (distance * conversion)**2
    D = r/(2*len(np.loadtxt(fileofradialdistances)))#diffusion constant
    k = (6*D*np.pi*9.125e-4*0.5e-6)/297    #Boltzmann constant
    Na = 8.31457/k   #Avagadro's Number
    
    err = abs((Na - 6.022e23)/6.022e23) * 100
    
    print 'The estimated Avagadro\'s number is %.4e' %(Na)
    print 'with a percent error of %.4f' %(err)

# %%
EstimateAvagadrosNumber('RadialDistances.txt')
# Out:
# The estimated Avagadro's number is 6.0704e+23
# with a percent error of 0.8033
