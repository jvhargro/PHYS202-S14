# %% [markdown]
# # ODE Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Question 1

# %% [markdown]
# For this question refer to the solutions for the simple pendulum we got using scipy's odeint from the beginning of the ODE Tour.
#
# (a) Use the numerical solution to see what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs. t for 5 different initial angles, θ0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot. What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4? What happens to the trajectory when the initial angle is 0 or π ?

# %%
def deriv(theta_current,t):  # return derivatives of the array theta
    g = 9.8 #m/s^2
    ell = 0.5 #m
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([ dtheta, domega ])
th0 = 0
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t) 
plt.plot(t,theta[:,0],label="0")
th0 = np.pi/4
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t) 
plt.plot(t,theta[:,0],label="pi/4")
th0 = np.pi/2
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t) 
plt.plot(t,theta[:,0],label="pi/2")
th0 = 3*np.pi/4
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t) 
plt.plot(t,theta[:,0],label="3pi/4")
th0 = np.pi
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t) 
plt.plot(t,theta[:,0],label="pi")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.ylim(-3,6)
plt.grid()
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ0 = 0.95π. Look carefully at their behavior. What is going on in these figures?

# %%
th0 = 0.95*np.pi
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t)

# %%
plt.plot(t,theta[:,0],label=".95pi")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.legend(loc='best')
plt.show()

plt.figure
plt.plot(t,theta[:,1],label="omega")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega (rad)$',fontsize=20)
plt.legend(loc='best')
plt.show()

plt.figure
plt.plot(theta[:,0],theta[:,1],label="omega vs. theta")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega (rad)$',fontsize=20)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# (c) For the θ0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E/m=gℓ(1-cos(θ)+12ℓ2ω2 ).
#
# Is the energy a constant? If not, then the computational errors are producing a non-physical loss (or gain) of energy. Review the documentation for odeint and change the error tolerance value to a tighter number.

# %%
th0 = 0.95*np.pi
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t,rtol=1.0) 
Em = 9.8*0.5*(1. - np.cos(theta[:,0])) + 0.5*(0.5**2.)*(theta[:,1]**2.)

plt.figure
plt.plot(t,Em,label="E/m")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$E/m$',fontsize=20)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ0=π−0.000001 ?

# %%
th0 = np.pi
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t,rtol=0.9) 

plt.plot(t,theta[:,0],label="pi")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.legend(loc='best')
plt.show()

plt.figure
plt.plot(t,theta[:,1],label="omega")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\omega (rad)$',fontsize=20)
plt.legend(loc='best')
plt.show()

Em = 9.8*0.5*(1. - np.cos(theta[:,0])) + 0.5*(0.5**2.)*(theta[:,1]**2.)

plt.figure
plt.plot(t,Em,label="E/m")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$E/m$',fontsize=20)
plt.legend(loc='best')

plt.show()

th0 = np.pi - 0.000001
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t, rtol=0.9) 

plt.figure
plt.plot(t,theta[:,0],label="pi-0.000001")
th0 = np.pi
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0. 
theta_init = np.array([th0, omega0])
theta = odeint(deriv,theta_init,t,rtol=0.9) 
plt.plot(t,theta[:,0],label="pi")
plt.xlabel(r'$t (seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize=20)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Question 2

# %% [markdown]
# (a) Use Euler's method (not odeint) to solve the following first-order differential equation with given initial condition y(0) = 0.
#
# dydx=x+2y
#
# Find the value of y when x = 1, y(1), using two different step sizes: 0.25 then 0.02.

# %%
xmax = 10
dx = 0.25 # time step
   
nsteps = int(xmax/dx)
x = np.zeros(nsteps)
y1 = np.zeros(nsteps)
 
y1[0] = 0.

for i in range(len(x)-1):
    x[i+1] = x[i] + dx
    y1[i+1] = y1[i] + (dx * (x[i] + 2*y1[i]))
    
print "y(1) with a step size of 0.25 =", y1[1./dx]

xmax = 10
dx2 = 0.02 # time step
   
nsteps = int(xmax/dx2)
x2 = np.zeros(nsteps)
y2 = np.zeros(nsteps)
y2[0] = 0.

for i in range(len(x2)-1):
    x2[i+1] = x2[i] + dx2
    y2[i+1] = y2[i] + (dx2 * (x2[i] + 2*y2[i]))
    

print "y(1) with a step size of 0.02 =", y2[1./dx2]
# Out:
# y(1) with a step size of 0.25 = 0.515625
# y(1) with a step size of 0.02 = 1.02667083657

# %% [markdown]
# (b) Plot the results from part (a) for the two different step sizes with the exact solution
#
# y=0.25e2x−0.5x−0.25
#
# on one plot. Include a legend. Which step size gives a more accurate result?

# %%
y3 = 0.25*exp(2*x) - 0.5*x - 0.25
plt.plot(x,y1,"r-",label="y(t) step size 0.25")
plt.plot(x2,y2,"b-",label="y(t) step size 0.02")
plt.plot(x,y3,"k-",label="yexact")
plt.xlabel("x",fontsize=20)
plt.ylabel("y",fontsize=20)
plt.grid()
plt.ylim(0,10)
plt.xlim(0,3)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# (c) Now solve the same problem using Euler-Cromer and the Midpoint method for the same pair of step sizes and plot the results along with the exact solution. Then also plot the difference between the approximate numerical solutions and the exact solution. Which combination of method and step-size gives the best result?

# %%
xmax = 10
dx = 0.25 # time step
   
nsteps = int(xmax/dx)
x = np.zeros(nsteps)
y1 = np.zeros(nsteps)
 
y1[0] = 0.

for i in range(len(x)-1):
    x[i+1] = x[i] + dx
    y1[i+1] = y1[i] + dx * (x[i+1] + 2*y1[i])
    
print "Euler Cromer y(1) with a step size of 0.25 =", y1[1./dx]

xmax = 10
dx2 = 0.02 # time step
   
nsteps = int(xmax/dx2)
x2 = np.zeros(nsteps)
y2 = np.zeros(nsteps)
y2[0] = 0.

for i in range(len(x2)-1):
    x2[i+1] = x2[i] + dx2
    y2[i+1] = y2[i] + dx2 * (x2[i+1] + 2*y2[i])
    

print "Euler Cromer y(1) with a step size of 0.02 =", y2[1./dx2]

plt.plot(x,y1,"r-",label="y(t) step size 0.25")
plt.plot(x2,y2,"b-",label="y(t) step size 0.02")
plt.plot(x,y3,"k-",label="yexact")
plt.xlabel("x",fontsize=20)
plt.ylabel("y",fontsize=20)
plt.grid()
plt.ylim(0,10)
plt.xlim(0,3)
plt.legend(loc="best")
plt.show()
# Out:
# Euler Cromer y(1) with a step size of 0.25 = 1.0234375
# Euler Cromer y(1) with a step size of 0.02 = 1.08773767003

# %%
xmax = 10
dx = 0.25 # time step
   
nsteps = int(xmax/dx)
x = np.zeros(nsteps)
y1 = np.zeros(nsteps)
 
y1[0] = 0.

for i in range(len(x)-1):
    x[i+1] = x[i] + dx
    y1[i+1] = y1[i] + dx * (0.5) *(x[i+1] + x[i] + 2*y1[i])
    
print "Midpoint y(1) with a step size of 0.25 =", y1[1./dx]

xmax = 10
dx2 = 0.02 # time step
   
nsteps = int(xmax/dx2)
x2 = np.zeros(nsteps)
y2 = np.zeros(nsteps)
y2[0] = 0.

for i in range(len(x2)-1):
    x2[i+1] = x2[i] + dx2
    y2[i+1] = y2[i] + dx2 * (0.5) *(x2[i+1] + x2[i] + 2*y2[i])
    

print "Midpoint y(1) with a step size of 0.02 =", y2[1./dx2]

plt.plot(x,y1,"r-",label="y(t) step size 0.25")
plt.plot(x2,y2,"b-",label="y(t) step size 0.02")
plt.plot(x,y3,"k-",label="yexact")
plt.xlabel("x",fontsize=20)
plt.ylabel("y",fontsize=20)
plt.grid()
plt.ylim(0,10)
plt.xlim(0,3)
plt.legend(loc="best")
plt.show()
# Out:
# Midpoint y(1) with a step size of 0.25 = 0.62158203125
# Midpoint y(1) with a step size of 0.02 = 0.708503909364

# %% [markdown]
# ### Question 3

# %% [markdown]
# We can use numerical solvers and widgets to explore the dynamics of a projectile that is subject to a drag force proportional to the square of its velocity - "quadratic drag".
#
# The force on the projectile is given by
#
# ∑F⃗ =ma⃗ =mg⃗ −cv2v^=mg⃗ −cvv⃗ =mg⃗ −cv2x+v2y−−−−−−√v⃗
#
# Where the second term is the drag force, in the direction opposite that of the velocity vector. Re-writing these in terms of the first-order differential equations for vx and vy gives
#
# mdvxdt=−cv2x+v2y−−−−−−√vx
#
# mdvydt=mg−cv2x+v2y−−−−−−√vy
#
# taking the positive y direction to be down. Notice that these are coupled equations. There are both vx and vy terms in each one. The drag coefficient c depends on the shape and density of the projectile. We can re-write this system of equations in terms of the terminal velocity - the point at which the gravitational force balances the drag force. This happens when mg=cv2. Let's denote the terminal velocity as vter=mg/c−−−−√ and re-write our equations in terms of vter.
#
# dvxdt=−gmvxv2terv2x+v2y−−−−−−√
#
# dvydt=−gm(1+vyv2terv2x+v2y−−−−−−√)
#
# (a) Create a derivative function to solve this system of equations and use odeint to solve it for a projectile fired at an angle of 50 degrees from the horizontal at an initial speed of 30 m/s. Track the projectile's motion over the time interval of 0 to 200 seconds and let (x0,y0) = (0,0). You'll have to calculate (vx0,vy0) from the information provided. Let vter=44 m/s. Plot the trajectory of the projectile (y vs. x) to see how far it can travel in the x direction before landing.

# %%
def derivproj(y,t):
    g = 9.8
    vter = 44.
    m=1.
    
   
    vx = y[0]
    vy = y[1]
    dvxdt = -(g/m)*(vx/vter**2) * sqrt(vx**2 + vy**2)
    dvydt = -(g/m)*(1. + (vy/vter**2) * sqrt(vx**2 + vy**2))
    return np.array([dvxdt,dvydt])

# %%
t = np.arange(0.,200.+0.01,0.01)
vx0 = 30.*np.cos(50.*pi/180.)
vy0 = 30.*np.sin(50.*pi/180.)
ans = odeint(derivproj,np.array([vx0,vy0]),t)

vx1 = ans[:,0]
vy1 = ans[:,1]

x = np.zeros(len(vx1))
y = np.zeros(len(vy1))
x[0] = 0.
y[0] = 0.

for i in range(len(vx1)-1):
    x[i+1] = x[i] + vx1[i] * 0.01
for b in range(len(vy1)-1):
    y[b+1] = y[b] + vy1[b] * 0.01

d = np.zeros(20001)
plt.plot(x,y)
plt.xlim(0,70)
plt.ylim(-10,50)
plt.plot(t,d)
plt.show()

# %% [markdown]
# (b) Now create an interact object that uses sliders for the initial speed, terminal velocity, launch angle, and time. Have it plot two curves - one representing the solution with quadratic drag and the other in the absence of drag:
#
# x(t)=x0+vx0t
# y(t)=y0+vy0t−12gt2

# %%
from IPython.html.widgets import interact, interactive


def derivproj2(m,vter,t,y):
    g = 9.8
    
   
    vx = y[0]
    vy = y[1]
    dvxdt = -(g/m)*(vx/vter**2) * sqrt(vx**2 + vy**2)
    dvydt = -(g/m)*(1. + (vy/vter**2) * sqrt(vx**2 + vy**2))
    return np.array([dvxdt,dvydt])

# %%
def intderivproj(angle = 50.,m = 1,vter = 44.,t = 100.):
    g = 9.8
    vter = 44.
    
    t1 = np.arange(0.,t+0.01,0.01)
    vx0 = 30.*np.cos(angle*pi/180.)
    vy0 = 30.*np.sin(angle*pi/180.)
    y = np.array([vx0,vy0])
    vx = y[0]
    vy = y[1]
    dvxdt = -(g/m)*(vx/vter**2) * sqrt(vx**2 + vy**2)
    dvydt = -(g/m)*(1. + (vy/vter**2) * sqrt(vx**2 + vy**2))
    np.array([dvxdt,dvydt])
    ans = odeint(derivproj,np.array([vx0,vy0]),t1)
    
    vx1 = ans[:,0]
    vy1 = ans[:,1]

    x = np.zeros(len(vx1))
    y = np.zeros(len(vy1))
    x[0] = 0.
    y[0] = 0.

    for i in range(len(vx1)-1):
        x[i+1] = x[i] + vx1[i] * 0.01
    for b in range(len(vy1)-1):
        y[b+1] = y[b] + vy1[b] * 0.01

    plt.plot(x,y)
    plt.xlim(0,120)
    plt.ylim(0,100)
    plt.show()
    
    x2 = x[0] + vx0*t1
    y2 = y[0] + vy0*t1 - (0.5)*g*t1**2
    plt.figure
    plt.plot(x2,y2)
    plt.xlim(0,120)
    plt.ylim(0,100)
    

v = interact(intderivproj,angle=(0.,90.,0.01),m=(0.,120,1.),vter=(0.,55.),t=(0.,200.))

# %% [markdown]
# (c) Use your interact object to find 3 pairs of initial angle and speed needed for the following projectiles to reach a target 80 m away. How do the values change if there is no air resistance? Put your results in a table for easier reading.
# Projectile 	Terminal velocity (m/s) 	Initial height (m)
# Golfball 	44 	0
# Baseball 	43 	1.5
# Pumpkin 	107 	1.5

# %% [markdown]
# Couldn't get mass and terminal velocity to be factors in my widget. All that changes the graphs is the angle.
