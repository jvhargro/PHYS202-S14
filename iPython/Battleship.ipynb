# %% [markdown]
# # BATTLESHIP!

# %% [markdown]
# ### Simply run the code, enter the number of turns you would like, and try to guess the location of the 3 block long ship in the 10 by 10 grid, good luck!

# %% [markdown]
# the cell below is the testing cell with notes, the 2nd cell is a demo of the game without cheater code

# %%
from ipythonblocks import BlockGrid
from ipythonblocks import colors
from random import randint
print "Let's play Battleship!"
print "Hits are shown in Red and misses in Black"
game = int(raw_input("How many turns would you like? (Hint: you're going to need at least 3)"))

board = BlockGrid(10,10, fill=(173, 216, 230))
board.show()

def random_row(board):
    return randint(1, 8)

def random_col(board):
    return randint(1, 8)

ship_row = random_row(board) 
ship_row2 = ship_row + 1
ship_row3 = ship_row + 2
ship_col = random_col(board)
ship_col2 = ship_col + 1
ship_col3 = ship_col + 2 #this makes the ship diagonal with a length of 3 and consequently harder to guess

ship = board[ship_row - 1, ship_col - 1] 
ship2 = board[ship_row2 - 1, ship_col2 - 1]
ship3 = board[ship_row3 - 1, ship_col3 - 1]

print ship_row  #these 'cheater' columns are for testing and are taken out in the next cell
print ship_row2
print ship_row3
print ship_col
print ship_col2
print ship_col3 

c = 0
var_miss = 0
var_miss2 = 0


for turn in range(game):
    print  "Turn", turn + 1
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))
    
    
    if guess_row == ship_row and guess_col == ship_col:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow = guess_row
        var_hitcol = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    elif guess_row == ship_row2 and guess_col == ship_col2:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow1 = guess_row
        var_hitcol1 = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    elif guess_row == ship_row3 and guess_col == ship_col3:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow2 = guess_row
        var_hitcol2 = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    else:
        if (guess_row < 1 or guess_row > 10) or (guess_col < 1 or guess_col > 10):
            print "Oops, that's not even in the ocean."
            board.show()#if this happens on last step, the "Game Over" if statement will not run
#side note, the below only works if player guessed the same block as the previous step, using block colors as conditions didn't work
        elif  var_miss == guess_row and var_miss2 == guess_col:
            print "You guessed that one already."
            board.show()
        else:
            if turn == game - 1:
                print "Game Over"
                print "Ship location shown in Green"
                board[ship_row - 1, ship_col - 1] = colors['Green']
                board[ship_row2 - 1, ship_col2 - 1] = colors['Green']
                board[ship_row3 - 1, ship_col3 - 1] = colors['Green']
            else:
                print "You missed my battleship!"
                board[guess_row - 1, guess_col - 1] = colors['Black']
                var_miss = guess_row
                var_miss2 = guess_col
                board.show()
board.show()

# %% [markdown]
# DEMO 1: repeat miss, off the board, and a sunken battleship

# %%
from ipythonblocks import BlockGrid
from ipythonblocks import colors
from random import randint
print "Let's play Battleship!"
print "Hits are shown in Red and misses in Black"
game = int(raw_input("How many turns would you like? (Hint: you're going to need at least 3)"))

board = BlockGrid(10,10, fill=(173, 216, 230))
board.show()

def random_row(board):
    return randint(1, 8)

def random_col(board):
    return randint(1, 8)

ship_row = random_row(board) 
ship_row2 = ship_row + 1
ship_row3 = ship_row + 2
ship_col = random_col(board)
ship_col2 = ship_col + 1
ship_col3 = ship_col + 2 #this makes the ship diagonal with a length of 3 and consequently harder to guess

ship = board[ship_row - 1, ship_col - 1] 
ship2 = board[ship_row2 - 1, ship_col2 - 1]
ship3 = board[ship_row3 - 1, ship_col3 - 1]

c = 0
var_miss = 0
var_miss2 = 0


for turn in range(game):
    print  "Turn", turn + 1
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))
    
    
    if guess_row == ship_row and guess_col == ship_col:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow = guess_row
        var_hitcol = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    elif guess_row == ship_row2 and guess_col == ship_col2:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow1 = guess_row
        var_hitcol1 = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    elif guess_row == ship_row3 and guess_col == ship_col3:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow2 = guess_row
        var_hitcol2 = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    else:
        if (guess_row < 1 or guess_row > 10) or (guess_col < 1 or guess_col > 10):
            print "Oops, that's not even in the ocean."
            board.show()#if this happens on last step, the "Game Over" if statement will not run
#side note, the below only works if player guessed the same block as the previous step, using block colors as conditions didn't work
        elif  var_miss == guess_row and var_miss2 == guess_col:
            print "You guessed that one already."
            board.show()
        else:
            if turn == game - 1:
                print "Game Over"
                print "Ship location shown in Green"
                board[ship_row - 1, ship_col - 1] = colors['Green']
                board[ship_row2 - 1, ship_col2 - 1] = colors['Green']
                board[ship_row3 - 1, ship_col3 - 1] = colors['Green']
            else:
                print "You missed my battleship!"
                board[guess_row - 1, guess_col - 1] = colors['Black']
                var_miss = guess_row
                var_miss2 = guess_col
                board.show()
board.show()
# Out:
# Let's play Battleship!
# Hits are shown in Red and misses in Black
# How many turns would you like? (Hint: you're going to need at least 3)10
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks56a6ee2f-f9d3-4689-bb54-d0c76197bca5 td {border: 1px solid white;}</style><table id="blocks56a6ee2f-f9d3-4689-bb54-d0c76197bca5" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="wi ...
# Turn 1
# Guess Row:1
# Guess Col:1
# Hit!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks5fd847d4-8958-4301-9852-545a7d522669 td {border: 1px solid white;}</style><table id="blocks5fd847d4-8958-4301-9852-545a7d522669" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="width: 20p ...
# Turn 2
# Guess Row:7
# Guess Col:8
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksba4e1752-7bcc-43e9-b725-fd3a3ff70bd0 td {border: 1px solid white;}</style><table id="blocksba4e1752-7bcc-43e9-b725-fd3a3ff70bd0" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="width: 20p ...
# Turn 3
# Guess Row:7
# Guess Col:8
# You guessed that one already.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf59ff8e5-6882-40e0-afef-ca80d1b66a2f td {border: 1px solid white;}</style><table id="blocksf59ff8e5-6882-40e0-afef-ca80d1b66a2f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="width: 20p ...
# Turn 4
# Guess Row:11
# Guess Col:12
# Oops, that's not even in the ocean.
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks566492e6-b142-4bc9-982d-060a8c79591d td {border: 1px solid white;}</style><table id="blocks566492e6-b142-4bc9-982d-060a8c79591d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="width: 20p ...
# Turn 5
# Guess Row:2
# Guess Col:2
# Hit!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksf39518ea-da15-412b-ab05-3376ba3e8b4c td {border: 1px solid white;}</style><table id="blocksf39518ea-da15-412b-ab05-3376ba3e8b4c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="width: 20px; heigh ...
# Turn 6
# Guess Row:3
# Guess Col:3
# Hit!
# Congratulations, you sunk my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4a9bc4ab-2ade-47aa-ad63-d0516f16d18a td {border: 1px solid white;}</style><table id="blocks4a9bc4ab-2ade-47aa-ad63-d0516f16d18a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (255, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(255, 0, 0);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px; ...

# %% [markdown]
# DEMO 2: All misses will result in the board showing the ship location

# %%
from ipythonblocks import BlockGrid
from ipythonblocks import colors
from random import randint
print "Let's play Battleship!"
print "Hits are shown in Red and misses in Black"
game = int(raw_input("How many turns would you like? (Hint: you're going to need at least 3)"))

board = BlockGrid(10,10, fill=(173, 216, 230))
board.show()

def random_row(board):
    return randint(1, 8)

def random_col(board):
    return randint(1, 8)

ship_row = random_row(board) 
ship_row2 = ship_row + 1
ship_row3 = ship_row + 2
ship_col = random_col(board)
ship_col2 = ship_col + 1
ship_col3 = ship_col + 2 #this makes the ship diagonal with a length of 3 and consequently harder to guess

ship = board[ship_row - 1, ship_col - 1] 
ship2 = board[ship_row2 - 1, ship_col2 - 1]
ship3 = board[ship_row3 - 1, ship_col3 - 1]


c = 0
var_miss = 0
var_miss2 = 0


for turn in range(game):
    print  "Turn", turn + 1
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))
    
    
    if guess_row == ship_row and guess_col == ship_col:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow = guess_row
        var_hitcol = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    elif guess_row == ship_row2 and guess_col == ship_col2:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow1 = guess_row
        var_hitcol1 = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    elif guess_row == ship_row3 and guess_col == ship_col3:
        print "Hit!"
        board[guess_row - 1, guess_col - 1] = colors['Red']
        c = c+1
        var_hitrow2 = guess_row
        var_hitcol2 = guess_col
        if c == 3:
            print "Congratulations, you sunk my battleship!"
            break
        else:
            board.show()
    else:
        if (guess_row < 1 or guess_row > 10) or (guess_col < 1 or guess_col > 10):
            print "Oops, that's not even in the ocean."
            board.show()#if this happens on last step, the "Game Over" if statement will not run
#side note, the below only works if player guessed the same block as the previous step, using block colors as conditions didn't work
        elif  var_miss == guess_row and var_miss2 == guess_col:
            print "You guessed that one already."
            board.show()
        else:
            if turn == game - 1:
                print "Game Over"
                print "Ship location shown in Green"
                board[ship_row - 1, ship_col - 1] = colors['Green']
                board[ship_row2 - 1, ship_col2 - 1] = colors['Green']
                board[ship_row3 - 1, ship_col3 - 1] = colors['Green']
            else:
                print "You missed my battleship!"
                board[guess_row - 1, guess_col - 1] = colors['Black']
                var_miss = guess_row
                var_miss2 = guess_col
                board.show()
board.show()
# Out:
# Let's play Battleship!
# Hits are shown in Red and misses in Black
# How many turns would you like? (Hint: you're going to need at least 3)2
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksc2b1b0de-05b3-44c8-b142-58cac83f0b27 td {border: 1px solid white;}</style><table id="blocksc2b1b0de-05b3-44c8-b142-58cac83f0b27" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="wi ...
# Turn 1
# Guess Row:1
# Guess Col:3
# You missed my battleship!
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb165c93e-28d5-4737-85e9-4bbf04e2c71f td {border: 1px solid white;}</style><table id="blocksb165c93e-28d5-4737-85e9-4bbf04e2c71f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="width: 20px; h ...
# Turn 2
# Guess Row:3
# Guess Col:5
# Game Over
# Ship location shown in Green
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksfdb6f464-1a1d-4074-b006-825c3b597a9f td {border: 1px solid white;}</style><table id="blocksfdb6f464-1a1d-4074-b006-825c3b597a9f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 3]&#10;Color: (0, 128, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 128, 0);"></td><td title="Index: [2, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [2, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 2 ...
